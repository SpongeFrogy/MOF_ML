# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('../cleaner/5k_with_symmetry.csv', sep=',', index_col=0)

# %%
data
# Out:
#                                                      mofid  \
# cifname
# 1100140  Cl[Cu]O[Cu]O[Cu]Cl.O=[C]1=NC=CC=N1.n1ccc(cc1)c...
# 1100722  [Fe][O]([Fe])[Fe].[O-]C(=O)c1ccc(cc1)C(=O)[O-]...
# 1501627  [In].[O-]C(=O)C1=C[C]=CC(=C1)C(=O)[O-] MOFid-v...
# 1501629  [In].[O-]C(=O)c1cc(cc(c1)C(=O)[O-])c1c(F)c(F)c...
# 1501771  [O-]C(=O)c1cc(cc(c1)C(=O)[O-])C(=O)[O-].[O][Zn...
# ...                                                    ...
# 8000359  C1CN2CCN1CC2.[O-]C(=O)c1ccc(cc1)C(=O)[O-].[OH4...
# 8000369  C1CN2CCN1CC2.[O-]C(=O)c1ccc(cc1)C(=O)[O-].[O][...
# 8000378  [C]1CN2CCN1CC2.[O-]C(=O)c1ccc(cc1)C(=O)[O-].[O...
# 8000387  [CH2]N1CCN(CC1)[CH2].[O-]C(=O)c1ccc(cc1)C(=O)[...
# 8000505  [O-]C(=O)c1ccc(cc1)C#Cc1c(F)c(F)c(c(c1F)F)C#Cc...
#
#                                                  mofkey  \
# cifname
# 1100140  Cu.BSACTHHIMKWVLX.MWVTWFVJZLCBMC.MOFkey-v1.hxl
# 1100722                 Fe.KKEYFWRCBNTPAC.MOFkey-v1.acs
# 1501627                 In.GZJYHAYPVZNUJX.MOFkey-v1.sql
# ...

# %%
mofkeyValues = data.mofkey.value_counts()[data.mofkey.value_counts() > 1]

# %%
mofkeyValues.size
# Out:
# 167

# %%
listOfDub = [data.loc[data.mofkey == mofkeyValues.index[i]] for i in range(mofkeyValues.size)]

# %%
listOfDub[0] # с 34 по паре
# Out:
#                                                      mofid  \
# cifname
# 7029788  [Ag].n1ccc(cc1)C1=NC(=[N]=C([N]1)c1ccncc1)c1cc...
# 7029801  [Ag].n1ccc(cc1)C1=NC(=[N]=C([N]1)c1ccncc1)c1cc...
# 7029814  [Ag].n1ccc(cc1)C1=NC(=[N]=C([N]1)c1ccncc1)c1cc...
# 7029823  [Ag].n1ccc(cc1)C1=NC(=[N]=C([N]1)c1ccncc1)c1cc...
# 7120533  CCCC1c2cc(c(cc2[O])[O])C(CCC)c2cc(C(c3cc(C(c4c...
# 7120586  [O-]C(=O)c1ccc(cc1)Oc1ccc(cc1)C(=O)[O-].[Zn] M...
# 7121298  [O-]C(=O)C.[O-]C(=O)c1ccc(cc1)P(c1ccc(cc1)C(=O...
# 7121336  [O-]C(=O)c1ccc(cc1)N(c1ccc(cc1)C(=O)[O-])c1ccc...
# 7121337  [C]CN(C(C12[C]C3(C2([O])[C]C3(C2[CH][N][N]2)C(...
# 7121563  [N]c1cc(cc(c1)C(=O)[O-])C(=O)[O-].[O-]C(=O)c1c...
#
#                                   mofkey  \
# cifname
# 7029788  Ag.CBMYFVSIIYILRH.MOFkey-v1.ths
# 7029801  Ag.CBMYFVSIIYILRH.MOFkey-v1.ths
# 7029814  Ag.CBMYFVSIIYILRH.MOFkey-v1.ths
# 7029823  Ag.CBMYFVSIIYILRH.MOFkey-v1.ths
# 7120533  Ag.CBMYFVSIIYILRH.MOFkey-v1.ths
# 7120586  Ag.CBMYFVSIIYILRH.MOFkey-v1.ths
# ...

# %%
dubDict = {}
# Out:
# 7029788
