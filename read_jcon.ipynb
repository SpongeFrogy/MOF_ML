# %%
import json
import gzip
import os
from mpcontribs.client import Client

# %%
# get is from downloaded list
# get client.get_contribution('id')
client = Client('lLAJ8zEg3W3x7jweMMUnD5f5zI5vmw24')

for json100 in list(os.walk(r"20k\contributions"))[0][2]:
    with gzip.open(f"20k/contributions/{json100}", 'r') as fin:
        qmofs = json.loads(fin.read().decode('utf-8'))
        for qmof in qmofs:
            with open(f"20k\qmof_data\{qmof['id']}.json", "w") as outfile:
                json.dump(client.get_contribution(qmof['id'])['data'], outfile)

# %%
for json100 in list(os.walk(r"20k\contributions"))[0][2]:
    print(json100)
# Out:
# 039efabeb4901447af34eb523d240ec6.json.gz
# 05067adda13367b3256a60be343fd6df.json.gz
# 09cfe8abc43395bd51fa2dff635300eb.json.gz
# 0a379204bddb1fcb45d622931ac8c49d.json.gz
# 0b5442da5e37c9a24fa1c4e087b53b4e.json.gz
# 0bc26a7055a783d4e2e2c71fd8fbc334.json.gz
# 0c24692f6150e71e8f994dfb6664002c.json.gz
# 0c984ab53d760e588a61e9ff31f75bb4.json.gz
# 0d1d858ce0785d1140dcbc1b191e5fab.json.gz
# 0d727ef5d291b1fd118b49ae2350a814.json.gz
# 0d8c3103a2d56e86d124e2382fc3535d.json.gz
# 0f493846922ebe5b854d459d2c7b2ec9.json.gz
# 108e5eced0bddd21ca497c660ca07bf3.json.gz
# 110429be922146e7d39d370852227e3b.json.gz
# 128d2347dd1cbc03d0a7679b3e527606.json.gz
# 136bcaa2a9ace8878433106b6d51a105.json.gz
# 13a056a6bbd9b884d7f370b55532777b.json.gz
# 13e900d6777171236929462c1b71c772.json.gz
# 13f827e6df4e95a3779e4ca28d64e4cf.json.gz
# 14f81ce22a278bd955df2f033dadcdf8.json.gz
# 151cc0483934779edd873c3b860c1ec0.json.gz
# 16b4f6db9ed6e0e67453447134c8a842.json.gz
# 1704b02f1dbaca3714fc8f66db305ff3.json.gz
# ...

# %%
data[0]['id']
# Out:
# '6196ce0ff8a517a48b6cab4f'

# %%
list(os.walk(r"20k\contributions"))
# Out:
# [('20k\\contributions',
#   [],
#   ['039efabeb4901447af34eb523d240ec6.json.gz',
#    '05067adda13367b3256a60be343fd6df.json.gz',
#    '09cfe8abc43395bd51fa2dff635300eb.json.gz',
#    '0a379204bddb1fcb45d622931ac8c49d.json.gz',
#    '0b5442da5e37c9a24fa1c4e087b53b4e.json.gz',
#    '0bc26a7055a783d4e2e2c71fd8fbc334.json.gz',
#    '0c24692f6150e71e8f994dfb6664002c.json.gz',
#    '0c984ab53d760e588a61e9ff31f75bb4.json.gz',
#    '0d1d858ce0785d1140dcbc1b191e5fab.json.gz',
#    '0d727ef5d291b1fd118b49ae2350a814.json.gz',
#    '0d8c3103a2d56e86d124e2382fc3535d.json.gz',
#    '0f493846922ebe5b854d459d2c7b2ec9.json.gz',
#    '108e5eced0bddd21ca497c660ca07bf3.json.gz',
#    '110429be922146e7d39d370852227e3b.json.gz',
#    '128d2347dd1cbc03d0a7679b3e527606.json.gz',
#    '136bcaa2a9ace8878433106b6d51a105.json.gz',
#    '13a056a6bbd9b884d7f370b55532777b.json.gz',
#    '13e900d6777171236929462c1b71c772.json.gz',
#    '13f827e6df4e95a3779e4ca28d64e4cf.json.gz',
# ...
