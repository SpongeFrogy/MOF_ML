# %%
from funcs import Dataset

# %%
data = Dataset('../cleaner/5k_with_symmetry.csv')

# %%
data.df['mofid'][1100140]
# Out:
# 'Cl[Cu]O[Cu]O[Cu]Cl.O=[C]1=NC=CC=N1.n1ccc(cc1)c1ccncc1 MOFid-v1.hxl.cat1'

# %%
data.tokenize_column('mofid')
# Out:
# {'Cl[Cu]O[Cu]O[Cu]Cl.O=[C]1=NC=CC=N1.n1ccc(cc1)c1ccncc1 MOFid-v1.hxl.cat1': 0,
#  '[Fe][O]([Fe])[Fe].[O-]C(=O)c1ccc(cc1)C(=O)[O-] MOFid-v1.acs.cat0': 1,
#  '[In].[O-]C(=O)C1=C[C]=CC(=C1)C(=O)[O-] MOFid-v1.sql.cat1': 2,
#  '[In].[O-]C(=O)c1cc(cc(c1)C(=O)[O-])c1c(F)c(F)c(c(c1F)F)c1cc(cc(c1)C(=O)[O-])C(=O)[O-] MOFid-v1.pts,tfi.cat0': 3,
#  '[O-]C(=O)c1cc(cc(c1)C(=O)[O-])C(=O)[O-].[O][Zn][Zn][O] MOFid-v1.tbo.cat0': 4,
#  'COC(=O)c1cc(cc(c1)C(=O)[O-])C(=O)[O-].[O-]C(=O)c1cc(cc(c1)C(=O)[O-])C(=O)[O-].[OH2][Cu][Cu][OH2] MOFid-v1.kgm.cat0': 5,
#  '[C][Mn]1([C])([C])([C])N2C=C(C=CC2=C2N1C=C(C=C2)C(=O)[O-])C(=O)[O-].[Mn].[O-]C(=O)C1=CC=C2N([CH]1)[Mn]([C])([C])([C])([C])N1[C]2C=CC(=C1)C(=O)[O-] MOFid-v1.dmd.cat0': 6,
#  '[Cu][Cu].[O-]C(=O)c1cc(O[C]2[C][C][C]2)c(c2c1cc(cc2)C(=O)[O-])c1c(O[C]2[C][C][C]2)cc(c2c1ccc(c2)C(=O)[O-])C(=O)[O-] MOFid-v1.wbl,lqm.cat0': 7,
# ...

# %%
data.tokenize_df()

# %%
data.df
# Out:
#          mofid  mofkey  simples_nodes  simples_linkers  simples  topology  \
# cifname
# 1100140      0       0              0                0        0         0
# 1100722      1       1              1                1        1         1
# 1501627      2       2              2                2        2         2
# 1501629      3       3              2                3        3         3
# 1501771      4       4              3                4        4         4
# ...        ...     ...            ...              ...      ...       ...
# 8000359   1548    1318            525             1037     1464         2
# 8000369   1549    1318            526             1037     1465         2
# 8000378   1550    1319            361             1038     1466         2
# 8000387   1551    1320            361             1039     1467         2
# 8000505   1552    1321            527              261     1468        31
#
#          cat  _cell_length_a  _cell_length_b  _cell_length_c  \
# ...

# %%
data.df.dtypes
# Out:
# mofid                                int64
# mofkey                               int64
# simples_nodes                        int64
# simples_linkers                      int64
# simples                              int64
# topology                             int64
# cat                                float64
# _cell_length_a                     float64
# _cell_length_b                     float64
# _cell_length_c                     float64
# _cell_angle_alpha                  float64
# _cell_angle_beta                   float64
# _cell_angle_gamma                  float64
# _cell_volume                       float64
# _symmetry_space_group_name_Hall      int64
# dtype: object

# %%
data.token_dicts['_symmetry_space_group_name_Hall']
# Out:
# {'P 2 -2n': 0,
#  'P -6c -2c': 1,
#  '-P 4c 2': 2,
#  '-I 4bd 2c': 3,
#  '-F 4 2 3': 4,
#  '-P 3 2"': 5,
#  '-P 2a 2bc': 6,
#  'I 4bw 2bw': 7,
#  '-R 3': 8,
#  '-P 4 2 3': 9,
#  '-P 2yn': 10,
#  '-P 2ybc': 11,
#  '-P 1': 12,
#  '-P 2ac 2n': 13,
#  '-I 2 2 3': 14,
#  'C -2yc': 15,
#  '-C 2yc': 16,
#  '-P 4ac 2b': 17,
#  'P -4': 18,
#  '-P 4ac 2ac': 19,
#  '-P 4 2n': 20,
#  '-I 2yc': 21,
#  '-P 2n 2ab': 22,
#  '-P 4 2': 23,
#  '-I 2b 2c 3': 24,
#  '-F 4vw 2vw 3': 25,
#  '-I 4 2 3': 26,
#  'P 2ac 2ab': 27,
#  'P 2yb': 28,
#  '-C 2y': 29,
#  '-I 4 2': 30,
#  '-I 2 2': 31,
#  'I -4 2': 32,
#  'P 3': 33,
#  '-P 6c 2c': 34,
#  'P 2 -2ab': 35,
#  '-R 3 2"': 36,
#  '-P 2a 2ac': 37,
#  '-I 4ad': 38,
#  'I -4 2 3': 39,
#  '-F 2uv 2vw': 40,
#  '-P 2yc': 41,
#  '-P 3 2c': 42,
#  'P 62 2 (0 0 4)': 43,
#  'P 32 2"': 44,
#  'F 2 -2d': 45,
#  '-P 2ab 2ac': 46,
#  '-P 4n 2 3': 47,
#  '-P 2ac 2ab': 48,
#  '-P 2yac': 49,
#  '-I 2b 2': 50,
#  '-P 2 2': 51,
#  'P 2c -2': 52,
#  '-P 2y': 53,
# ...

# %%
data.scale_data()
# Out:
# C:\Users\droid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
data.df
# Out:
#             mofid    mofkey  simples_nodes  simples_linkers   simples  \
# cifname
# 1100140 -1.733508 -1.705177      -0.881130        -1.439031 -1.722363
# 1100722 -1.731277 -1.702549      -0.874440        -1.435833 -1.720009
# 1501627 -1.729046 -1.699921      -0.867749        -1.432635 -1.717655
# 1501629 -1.726815 -1.697293      -0.867749        -1.429437 -1.715301
# 1501771 -1.724584 -1.694664      -0.861059        -1.426239 -1.712947
# ...           ...       ...            ...              ...       ...
# 8000359  1.719947  1.758616       2.631398         1.877192  1.724093
# 8000369  1.722178  1.758616       2.638089         1.877192  1.726447
# 8000378  1.724409  1.761244       1.534151         1.880390  1.728801
# 8000387  1.726640  1.763872       1.534151         1.883588  1.731155
# 8000505  1.728871  1.766500       2.644779        -0.604379  1.733509
#
#          topology       cat  _cell_length_a  _cell_length_b  _cell_length_c  \
# cifname
# ...

# %%
data.token_dicts['mofid']
# Out:
# {'Cl[Cu]O[Cu]O[Cu]Cl.O=[C]1=NC=CC=N1.n1ccc(cc1)c1ccncc1 MOFid-v1.hxl.cat1': -1.7335075125775772,
#  '[Fe][O]([Fe])[Fe].[O-]C(=O)c1ccc(cc1)C(=O)[O-] MOFid-v1.acs.cat0': -1.7312765986650398,
#  '[In].[O-]C(=O)C1=C[C]=CC(=C1)C(=O)[O-] MOFid-v1.sql.cat1': -1.7290456847525024,
#  '[In].[O-]C(=O)c1cc(cc(c1)C(=O)[O-])c1c(F)c(F)c(c(c1F)F)c1cc(cc(c1)C(=O)[O-])C(=O)[O-] MOFid-v1.pts,tfi.cat0': -1.7268147708399653,
#  '[O-]C(=O)c1cc(cc(c1)C(=O)[O-])C(=O)[O-].[O][Zn][Zn][O] MOFid-v1.tbo.cat0': -1.7245838569274279,
#  'COC(=O)c1cc(cc(c1)C(=O)[O-])C(=O)[O-].[O-]C(=O)c1cc(cc(c1)C(=O)[O-])C(=O)[O-].[OH2][Cu][Cu][OH2] MOFid-v1.kgm.cat0': -1.7223529430148905,
#  '[C][Mn]1([C])([C])([C])N2C=C(C=CC2=C2N1C=C(C=C2)C(=O)[O-])C(=O)[O-].[Mn].[O-]C(=O)C1=CC=C2N([CH]1)[Mn]([C])([C])([C])([C])N1[C]2C=CC(=C1)C(=O)[O-] MOFid-v1.dmd.cat0': -1.7201220291023531,
# ...

# %%
data.dset2csv(path_or_buf='test.csv', sep=',')

# %%
data.dset2json(path_or_buf='test.json')

# %%
data.token2csv('mofid', 'mofid_test.csv')

# %%
data.token2json('mofid', 'mofid_test.json')
