# %%
import numpy as np
import pandas as pd
import sys

# %%
sys.path.insert(1, '../token_part')

# %%
from funcs import Dataset

# %%
data = Dataset('../cleaner/5k_with_symmetry.csv')

# %%
data.df
# Out:
#                                                      mofid  \
# cifname
# 1100140  Cl[Cu]O[Cu]O[Cu]Cl.O=[C]1=NC=CC=N1.n1ccc(cc1)c...
# 1100722  [Fe][O]([Fe])[Fe].[O-]C(=O)c1ccc(cc1)C(=O)[O-]...
# 1501627  [In].[O-]C(=O)C1=C[C]=CC(=C1)C(=O)[O-] MOFid-v...
# 1501629  [In].[O-]C(=O)c1cc(cc(c1)C(=O)[O-])c1c(F)c(F)c...
# 1501771  [O-]C(=O)c1cc(cc(c1)C(=O)[O-])C(=O)[O-].[O][Zn...
# ...                                                    ...
# 8000359  C1CN2CCN1CC2.[O-]C(=O)c1ccc(cc1)C(=O)[O-].[OH4...
# 8000369  C1CN2CCN1CC2.[O-]C(=O)c1ccc(cc1)C(=O)[O-].[O][...
# 8000378  [C]1CN2CCN1CC2.[O-]C(=O)c1ccc(cc1)C(=O)[O-].[O...
# 8000387  [CH2]N1CCN(CC1)[CH2].[O-]C(=O)c1ccc(cc1)C(=O)[...
# 8000505  [O-]C(=O)c1ccc(cc1)C#Cc1c(F)c(F)c(c(c1F)F)C#Cc...
#
#                                                  mofkey  \
# cifname
# 1100140  Cu.BSACTHHIMKWVLX.MWVTWFVJZLCBMC.MOFkey-v1.hxl
# 1100722                 Fe.KKEYFWRCBNTPAC.MOFkey-v1.acs
# 1501627                 In.GZJYHAYPVZNUJX.MOFkey-v1.sql
# ...

# %%
data.prepare_like_03_04()
# Out:
# C:\Users\droid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(

# %%
data.dset2csv(path_or_buf='dataset/03_04_prepare.csv')

# %%
for col in data.df.columns:
    data.token2csv(column=col,filename='dataset/'+col+'.csv' )

# %%
data.token_dicts['cell volume']
# Out:
# {4452.3: 0.005901079573179196,
#  2645.12: 0.003325090118614466,
#  20971.0: 0.029447155228685788,
#  18496.3: 0.025919669807636783,
#  2231.3: 0.0027352230571773234,
#  11680.9: 0.01620486634110857,
#  26455.4: 0.03726472545667349,
#  25643.0: 0.03610671472565146,
#  41583.0: 0.058827900166925594,
#  77322.0: 0.10977096456376978,
#  77319.0: 0.10976668830553114,
#  9136.0: 0.012577316477275538,
#  8305.0: 0.011392792945173981,
#  1270.33: 0.0013654377639840225,
#  1238.56: 0.0013201521892368907,
#  2120.0: 0.00257657387652401,
#  2563.6: 0.0032088899280766576,
#  2392.5: 0.0029650006665332446,
#  2470.4: 0.0030760408387964355,
#  834.7: 0.0007444823051520118,
#  847.4: 0.0007625851316955614,
#  20233.94: 0.028396535596229983,
#  1689.4: 0.0019627882773387752,
#  1076.6: 0.0010892912611271818,
#  3725.3: 0.004864799660016944,
#  912.35: 0.0008551661225619828,
#  2913.3: 0.0037073590967600686,
#  1611.5: 0.0018517481050755846,
#  7759.0: 0.010614513945742634,
# ...

# %%
# Убираем дубликаты

mofkeyValues = data.df.mofkey.value_counts()[data.df.mofkey.value_counts() > 1]

# %%
list(mofkeyValues.index)
# Out:
# ['Ag.CBMYFVSIIYILRH.MOFkey-v1.ths',
#  'Zn.KGBJURCYTWEKPT.MOFkey-v1.ggl',
#  'Cu.GZJYHAYPVZNUJX.MOFkey-v1.kgm',
#  'Th.VUYFKAXNJXFNFA.MOFkey-v1.bcu',
#  'Ag.MWVTWFVJZLCBMC.MOFkey-v1.sql',
#  'Zn.KKEYFWRCBNTPAC.MOFkey-v1.hxl',
#  'Cu.NSCIYASAEQYMAT.MOFkey-v1.iab',
#  'Ag.JTNXQVCPQMQLHK.MWVTWFVJZLCBMC.MOFkey-v1.sql',
#  'Cu.QMKYBPDZANOJGF.MOFkey-v1.tbo',
#  'CoAg.QBZOFHXSJWHZPL.MOFkey-v1.utp',
#  'Cu.RETJAAPEZMHASZ.MOFkey-v1.pts',
#  'Zn.BIDRRTBWQPURTN.MOFkey-v1.ggl',
#  'Zr.HVCDAMXLLUJLQZ.MOFkey-v1.csq',
#  'Zn.GZJYHAYPVZNUJX.MOFkey-v1.kgm',
#  'Zn.NEQFBGHQPUXOFH.MOFkey-v1.sql',
#  'Co.IMNIMPAHZVJRPE.KKEYFWRCBNTPAC.MOFkey-v1.sql',
#  'U.VUYFKAXNJXFNFA.MOFkey-v1.bcu',
#  'Cu.CPIYEXXYOQSGAM.MOFkey-v1.sql',
#  'Zr.RXOHFPCZGPKIRD.MOFkey-v1.bcu',
#  'Co.OBGWAPCFHDYOJW.MOFkey-v1.the',
#  'Cd.MESQWWFGNOQOMI.MOFkey-v1.dia',
#  'Cr.GRYXMEJPMFYXQG.MOFkey-v1.the',
#  'Zn.KKEYFWRCBNTPAC.MOFkey-v1.sql',
#  'Zr.VZCYOOQTPOCHFL.MOFkey-v1.fcu',
#  'Cu.TWBYWOBDOCUKOW.MOFkey-v1.bcu',
# ...

# %%
for mkey in mofkeyValues.index:
    data.df = data.df.drop(index=data.df.loc[data.df.mofkey==mkey].index)

# %%
data.df
# Out:
#                                                      mofid  \
# cifname
# 1100140  Cl[Cu]O[Cu]O[Cu]Cl.O=[C]1=NC=CC=N1.n1ccc(cc1)c...
# 1501627  [In].[O-]C(=O)C1=C[C]=CC(=C1)C(=O)[O-] MOFid-v...
# 1501629  [In].[O-]C(=O)c1cc(cc(c1)C(=O)[O-])c1c(F)c(F)c...
# 1501771  [O-]C(=O)c1cc(cc(c1)C(=O)[O-])C(=O)[O-].[O][Zn...
# 1508061  [C][Mn]1([C])([C])([C])N2C=C(C=CC2=C2N1C=C(C=C...
# ...                                                    ...
# 7711358  [OH2][Sm].[O]N1C(=O)c2ccc3c4c2c(C1=O)ccc4C(=O)...
# 7712002  [Cd].[O-]C(=O)c1ccc(cc1)OCc1cc(COc2ccc(cc2)C(=...
# 8000378  [C]1CN2CCN1CC2.[O-]C(=O)c1ccc(cc1)C(=O)[O-].[O...
# 8000387  [CH2]N1CCN(CC1)[CH2].[O-]C(=O)c1ccc(cc1)C(=O)[...
# 8000505  [O-]C(=O)c1ccc(cc1)C#Cc1c(F)c(F)c(c(c1F)F)C#Cc...
#
#                                                  mofkey  \
# cifname
# 1100140  Cu.BSACTHHIMKWVLX.MWVTWFVJZLCBMC.MOFkey-v1.hxl
# 1501627                 In.GZJYHAYPVZNUJX.MOFkey-v1.sql
# 1501629                 In.TYPODEXFRPHZNH.MOFkey-v1.pts
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
data.tokenize_df()
data.scale_data(MinMaxScaler())
# Out:
# C:\Users\droid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(

# %%
data.df = data.df.drop(['mofid', 'mofkey'], axis=1)

# %%
data.df
# Out:
#          simples_nodes  simples_linkers   simples  topology       cat  \
# cifname
# 1100140       0.000000         0.000000  0.000000  0.000000  0.142857
# 1501627       0.002421         0.001163  0.000887  0.004525  0.142857
# 1501629       0.002421         0.002326  0.001775  0.009050  0.000000
# 1501771       0.004843         0.003488  0.002662  0.013575  0.000000
# 1508061       0.007264         0.004651  0.003549  0.018100  0.000000
# ...                ...              ...       ...       ...       ...
# 7711358       0.997579         0.995349  0.996451  0.502262  0.000000
# 7712002       0.024213         0.997674  0.997338  0.040724  0.000000
# 8000378       0.704600         0.998837  0.998225  0.004525  0.000000
# 8000387       0.704600         1.000000  0.999113  0.004525  0.000000
# 8000505       1.000000         0.277907  1.000000  0.113122  0.142857
#
#                 a         b         c     alpha      beta     gamma  \
# cifname
# ...

# %%
data.df = data.df.reset_index().drop()
# Out:
#       cifname  simples_nodes  simples_linkers   simples  topology       cat  \
# 0     1100140       0.000000         0.000000  0.000000  0.000000  0.142857
# 1     1501627       0.002421         0.001163  0.000887  0.004525  0.142857
# 2     1501629       0.002421         0.002326  0.001775  0.009050  0.000000
# 3     1501771       0.004843         0.003488  0.002662  0.013575  0.000000
# 4     1508061       0.007264         0.004651  0.003549  0.018100  0.000000
# ...       ...            ...              ...       ...       ...       ...
# 1150  7711358       0.997579         0.995349  0.996451  0.502262  0.000000
# 1151  7712002       0.024213         0.997674  0.997338  0.040724  0.000000
# 1152  8000378       0.704600         0.998837  0.998225  0.004525  0.000000
# 1153  8000387       0.704600         1.000000  0.999113  0.004525  0.000000
# 1154  8000505       1.000000         0.277907  1.000000  0.113122  0.142857
#
# ...
