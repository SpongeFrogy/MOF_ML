# %%
from mpcontribs.client import Client

# %%
client = Client('lLAJ8zEg3W3x7jweMMUnD5f5zI5vmw24')
dir(client)
# Out:
# ['apikey',
#  'attachments',
#  'available_query_params',
#  'cached_swagger_spec',
#  'contributions',
#  'create_project',
#  'delete_contributions',
#  'download_attachments',
#  'download_contributions',
#  'download_structures',
#  'download_tables',
#  'from_spec',
#  'from_url',
#  'get_all_ids',
#  'get_attachment',
#  'get_contribution',
#  'get_model',
#  'get_project',
#  'get_structure',
#  'get_table',
#  'get_totals',
#  'get_unique_identifiers_flags',
#  'headers',
#  'headers_json',
#  'host',
#  'init_columns',
#  'is_equal',
#  'make_private',
#  'make_public',
#  'notebooks',
#  'project',
#  'projects',
#  'protocol',
#  'query_contributions',
#  'query_projects',
#  'session',
#  'structures',
#  'submit_contributions',
#  'swagger_spec',
#  'tables',
#  'update_contributions',
#  'url',
#  'version']

# %%
client.download_contributions(query={'project': "qmof", "data_contains": 'smiles'}, outdir='20k', overwrite=True)
# Out:
# ...
#   9%|9         | 19/204 [00:05<00:50,  3.68it/s]
# [{'attachments': [{'id': '6196c6e7a6be6ad338993952'},
#    {'id': '6196c6e7a6be6ad338993953'},
#    {'id': '6196c6e8a6be6ad338993954'}],
#   'data': {},
#   'formula': 'Ba2CuC6H14O16',
#   'id': '6196c6e8a6be6ad338993956',
#   'identifier': 'qmof-8a95c27',
#   'is_public': True,
#   'last_modified': '2021-11-18T21:34:32.204000',
#   'needs_build': False,
#   'notebook': {'id': '6196c74f50df78b44acf8f69'},
#   'project': 'qmof',
#   'structures': [{'id': '6196c6e7a6be6ad338993951'}],
#   'tables': []},
#  {'attachments': [{'id': '6196c6e8f8a517a48b6c34f4'},
#    {'id': '6196c6e8f8a517a48b6c34f5'},
#    {'id': '6196c6e8f8a517a48b6c34f6'}],
#   'data': {},
#   'formula': 'Gd2C30H30N2O16',
#   'id': '6196c6e8f8a517a48b6c34f7',
#   'identifier': 'qmof-3a7d3be',
#   'is_public': True,
#   'last_modified': '2021-11-18T21:34:32.296000',
#   'needs_build': False,
#   'notebook': {'id': '6196c75050df78b44acf8f6a'},
#   'project': 'qmof',
# ...

# %%
type(client.get_contribution("6196ce0ff8a517a48b6cab4f")['data'])
# Out:
# dict
